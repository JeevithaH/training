# %% [markdown]
# <a href="https://colab.research.google.com/github/JeevithaH/training/blob/main/downloadImages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sat Dec 16 09:14:47 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/NanoCode012/OIDv6_ToolKit_Download_Open_Images_Support_Yolo_Format.git
# Out:
# Cloning into 'OIDv6_ToolKit_Download_Open_Images_Support_Yolo_Format'...
# remote: Enumerating objects: 548, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 548 (delta 2), reused 5 (delta 2), pack-reused 542
# Receiving objects: 100% (548/548), 34.16 MiB | 36.52 MiB/s, done.
# Resolving deltas: 100% (218/218), done.

# %%
# !pip install -r /content/OIDv6_ToolKit_Download_Open_Images_Support_Yolo_Format/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 16.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 54.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.2/548.2 kB 42.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.0/82.0 kB 12.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9
#     Uninstalling rsa-4.9:
#       Successfully uninstalled rsa-4.9
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.18.1
#     Uninstalling docutils-0.18.1:
#       Successfully uninstalled docutils-0.18.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# ...

# %%
# !mkdir OID
# !mkdir OID/Dataset
# Out:
# mkdir: cannot create directory ‘OID’: File exists
# mkdir: cannot create directory ‘OID/Dataset’: File exists

# %%
classes = 'Handgun'
samples = 300

# !python /content/OIDv6_ToolKit_Download_Open_Images_Support_Yolo_Format/main.py downloader --classes {classes} --type_csv train --limit {samples}
# Out:
#     [INFO] |  saving dataset configurations at ./OID/Dataset/config.json
#
# 		   ___   _____  ______            _    _       _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |     | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_    |  | | |
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|     | | |
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_       | |
# 		 `.___.'|_____||______.'   \__/     |_____|     |_|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Handgun.
#    [ERROR] | Missing the class-descriptions-boxable.csv file.
# ...

# %%
# !zip -r /content/data.zip  /content/OID/Dataset/train/
# Out:
#   adding: content/OID/Dataset/train/ (stored 0%)
#   adding: content/OID/Dataset/train/Handgun/ (stored 0%)
#   adding: content/OID/Dataset/train/Handgun/labels/ (stored 0%)
#   adding: content/OID/Dataset/train/Handgun/labels/c726d838906b361d.txt (stored 0%)
#   adding: content/OID/Dataset/train/Handgun/labels/f9f89391c0f2a488.txt (deflated 16%)
#   adding: content/OID/Dataset/train/Handgun/labels/5d24572a419d7d0e.txt (deflated 24%)
#   adding: content/OID/Dataset/train/Handgun/labels/3afade0f14091716.txt (deflated 39%)
#   adding: content/OID/Dataset/train/Handgun/labels/37d2923e1d9f5044.txt (deflated 3%)
#   adding: content/OID/Dataset/train/Handgun/labels/3122ebb9cb449fa9.txt (deflated 17%)
#   adding: content/OID/Dataset/train/Handgun/labels/05a0dd0133e1c360.txt (deflated 5%)
#   adding: content/OID/Dataset/train/Handgun/labels/090897e8ebc8adf5.txt (stored 0%)
#   adding: content/OID/Dataset/train/Handgun/labels/3632ed446a133656.txt (deflated 7%)
# ...
